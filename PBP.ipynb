# %%
import pandas as pd

dfPlayer_sharks = pd.read_csv('C:\\Users\\Bastian Barraza M\\OneDrive\\Documentos\\sharksBasketball\\data\\sharksVSsfp_game1\\PBP_sharksVSsfb_game1.csv')

# %%
dfPlayer_sharks['pbp-logo src'].unique()
# Out:
# array([nan,
#        'https://se-img.dcd-production.i.geniussports.com/2486f00667ff3afc356daad5104c02e2T1.png',
#        'https://se-img.dcd-production.i.geniussports.com/c3e538b0395f1fdcfcbdef24c556c602T1.jpg'],
#       dtype=object)

# %%
dfPlayer_sharks.head(20)
# Out:
#                    pbp-action  \
# 0         COMIENZA EL PARTIDO
# 1              INICIO PERIODO
# 2              INICIO PERIODO
# 3              , Salto ganado
# 4             , Salto perdido
# 5               , 2PT bandeja
# 6                     , Tapón
# 7          , Rebote defensivo
# 8                       , 3PT
# 9          , Rebote defensivo
# 10              , 2PT bandeja
# 11         , Rebote defensivo
# 12     , Pérdida por mal pase
# 13             , Recuperación
# 14  , 2PT bandeja  convertido
# 15                      , 3PT
# 16           Rebote defensivo
# 17                      , 3PT
# 18          , Rebote ofensivo
# 19              , 2PT bandeja
#
#                                          pbp-logo src  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   https://se-img.dcd-production.i.geniussports.c...
# ...
